# %% [markdown]
# # AIED'24 H-index
#
# This notebook uses Publish or Perish command line tools to calculate metrics for the AIED PC
#
# ## IMPORTANT
#
# - It is best to get Google Scholar profile page URLS from the PC. In that case, only `retrieve_gs` and `metrics_gs` are needed, and there is no ambiguity (i.e. multiple profile pages with the same name)
# - If `search_gs` is used, names should match Google Scholar, e.g. if Google Scholar says "Christopher Conway", then "Chris Conway" is less likely to match

# %% [markdown]
# ## Utility functions

# %%
import subprocess
import sys
import re
from urllib.parse import urlparse, parse_qs
import spacy
import pandas as pd
import os.path

# query template for finding google scholar profile (returns N profiles)
search_gs_template = """./pop8query --gsauthor --author="#QUERY" data/#SAFENAME-SEARCH.csv"""

# query template for retrieving single google scholar profile, disambiguating from search above using N
retreive_gs_template = """./pop8query --gsprofile --author="#ID" data/#SAFENAME-#N.csv"""

# query template for metrics on google scholar profile, disambiguating from search above using N
metrics_gs_template = """./pop8metrics --label "#NAME" --format csvh "data/#SAFENAME-#N.csv" data/#SAFENAME-#N-METRICS.csv"""

# some weirdness with using subprocess, so trying !
def run_pop_command_line(params):
    # result = subprocess.run(bash_params(metrics_gs_template,name,n))
    # return result
    command = " ".join(params)
    print(command)
    # !{command}

def safe_name(name):
    return "".join(x for x in name if x.isalnum())
    
def bash_params(template,name,query="",n="",id=""):
    safe = safe_name(name)
    return [ x.replace("#QUERY",query).replace("#NAME",name).replace("#SAFENAME",safe).replace("#ID",id).replace("#N",n) for x in template.split(' ')]

def search_gs(query,name):
    params = bash_params(search_gs_template,name,query=query)
    run_pop_command_line(params)

def get_ids(name):
    safe = safe_name(name)
    with open(f'data/{safe}-SEARCH.csv', 'r') as f:
        text = f.read()
        urls = re.findall("https://scholar.google.com/citations[^\",']*", text)
        ids = [ parse_qs(urlparse(url).query)['user'][0] for url in urls ]
    return ids

nlp = spacy.load("en_core_web_md")

def get_top_search_result(name):
    safe = safe_name(name)
    df = pd.read_csv(f'data/{safe}-SEARCH.csv')
    aied = nlp("artificial intelligence education data mining learning")
    df['similarity'] = df['Source'].apply(lambda x: aied.similarity(nlp(x.replace('"', '').lower())) if not pd.isnull(x) else 0)
    df['scholar_id'] = df['ArticleURL'].apply(lambda x: parse_qs(urlparse(x).query)['user'][0] if not pd.isnull(x) else x)
    s = df.sort_values(by='similarity',ascending=False)['scholar_id']
    ranked_matches = list(zip(s,s.index))
    return ranked_matches[0]

def retreive_gs(name,n,id):
    params = bash_params(retreive_gs_template,name,n=n,id=id)
    run_pop_command_line(params)

def metrics_gs(name,n):
    params = bash_params(metrics_gs_template,name,n=n)
    run_pop_command_line(params)
    
def retrieve_results_exist(name,n):
    safe = safe_name(name)
    return os.path.isfile(f"data/{safe}-{n}.csv") 
    
def matches(name):
    count = 0
    try: 
        safe = safe_name(name)
        with open(f'data/{safe}-SEARCH.csv', 'r') as f:
            count = len(f.readlines())
    except:
        count = 0
    return count

# %% [markdown]
# ## Query loop
#
# **Assumes input file is TSV with name in first column and affiliation in second column**
#
# 1. I queried Google Scholar using the name and affiliation as given in the input file
#
# 2. If this returned no hits, I tried again without affiliation
#
# 3. If more than one Google Scholar profile matched, I used the keywords associated with that profile (if available) and did a semantic match with "artificial intelligence education data mining learning". I then used the profile with the highest match
#
# 4. Publication info for the "best" profile was downloaded and then metrics calculated. h-index is column "h" and citations is column "c"
#
# Possible errors:
#
# - A profile was never found. This seems to happen if the name in the file is the familiar name version of the formal name used in Google Scholar. Please see "missing-names.txt" for manual entry
#
# - A profile was found, but it is the wrong profile. In this case, there are usually multiple profiles and the wrong one was chosen. Please see the "best-guesses.txt" file for double checking

# %%
# !touch missing-names.txt

# %%
import time

#loop over all names and execute all queries
with open("AIED2024 PC List.csv") as file:
    names = [ (line.split("\t")[0]," ".join(line.split('\t')[0:2]).rstrip()) for line in file]
    for name,query in names:
        print(f"--------Searching: {query}")
        # Hack for cached data; if we have anything other than an exact match, use affiliation
        if matches(name) == 2:
            print("+++ using cached search")
        if matches(name) != 2:
            print("--- multiple hits on previous search. attempting to narrow.")
            search_gs(query,name)
        # If we have no matches, use name without affiliation
        if matches(name) == 0:
            print("!!! no hits. repeating search without affiliation")
            search_gs(name,name)
        print(f">>> we have {matches(name)-1} hits")
        #time.sleep(5)
        try:
            # ids = get_ids(name)
            #take the first id for now
            # index = 0
            url,index = get_top_search_result(name)
            if not retrieve_results_exist(name,str(index)):
                print(f"--- retrieving results for best match {index}")
                retreive_gs(name, str(index), url) #ids[index])
            time.sleep(5)
            print(">>> computing metrics")
            metrics_gs(name,str(index))
        except OSError:
            with open("missing-names.txt", "a") as f:
                f.write(f"{name}\n")
# Out:
# --------Searching: Abhijit Suresh University of Colorado Boulder
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Abhijit Suresh" --format csvh "data/AbhijitSuresh-0.csv" data/AbhijitSuresh-0-METRICS.csv
# data/AbhijitSuresh-0.csv: imported Publish or Perish (CSV) data; 21 publications
# --------Searching: Abhinava Barthakur University of South Australia
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Abhinava Barthakur" --format csvh "data/AbhinavaBarthakur-0.csv" data/AbhinavaBarthakur-0-METRICS.csv
# data/AbhinavaBarthakur-0.csv: imported Publish or Perish (CSV) data; 10 publications
# --------Searching: Adetunji Adeniran Carnegie Mellon University
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Adetunji Adeniran Carnegie Mellon University" data/AdetunjiAdeniran-SEARCH.csv
# Google Scholar Author
# Searching Adetunji Adeniran Carnegie Mellon University
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 2 hits
# >>> computing metrics
# ./pop8metrics --label "Adetunji Adeniran" --format csvh "data/AdetunjiAdeniran-0.csv" data/AdetunjiAdeniran-0-METRICS.csv
# data/AdetunjiAdeniran-0.csv: imported Publish or Perish (CSV) data; 17 publications
# --------Searching: Aditi Mallavarapu University of Illinois at Chicago
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Aditi Mallavarapu" --format csvh "data/AditiMallavarapu-0.csv" data/AditiMallavarapu-0-METRICS.csv
# data/AditiMallavarapu-0.csv: imported Publish or Perish (CSV) data; 13 publications
# --------Searching: Aditi Singh Kent State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Aditi Singh" --format csvh "data/AditiSingh-0.csv" data/AditiSingh-0-METRICS.csv
# data/AditiSingh-0.csv: imported Publish or Perish (CSV) data; 13 publications
# --------Searching: Akihiro Kashihara The University of Electro-Communications
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Akihiro Kashihara" --format csvh "data/AkihiroKashihara-0.csv" data/AkihiroKashihara-0-METRICS.csv
# data/AkihiroKashihara-0.csv: imported Publish or Perish (CSV) data; 547 publications
# --------Searching: Alberto Casas-Ortiz UNED
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Alberto Casas-Ortiz" --format csvh "data/AlbertoCasasOrtiz-0.csv" data/AlbertoCasasOrtiz-0-METRICS.csv
# data/AlbertoCasasOrtiz-0.csv: imported Publish or Perish (CSV) data; 10 publications
# --------Searching: Aldo Gordillo Universidad Politécnica de Madrid (UPM)
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Aldo Gordillo" --format csvh "data/AldoGordillo-0.csv" data/AldoGordillo-0-METRICS.csv
# data/AldoGordillo-0.csv: imported Publish or Perish (CSV) data; 56 publications
# --------Searching: Alessandro Vivas UFVJM
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Alessandro Vivas" --format csvh "data/AlessandroVivas-0.csv" data/AlessandroVivas-0-METRICS.csv
# data/AlessandroVivas-0.csv: imported Publish or Perish (CSV) data; 84 publications
# --------Searching: Alex Sandro Gomes Universidade Federal de Pernambuco
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Alex Sandro Gomes" --format csvh "data/AlexSandroGomes-0.csv" data/AlexSandroGomes-0-METRICS.csv
# data/AlexSandroGomes-0.csv: imported Publish or Perish (CSV) data; 465 publications
# --------Searching: Alexandra Cristea
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Alexandra Cristea" data/AlexandraCristea-SEARCH.csv
# Google Scholar Author
# Searching Alexandra Cristea
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# Progress: 2 (of 1000)
# 2 results found; 2 out of maximum 1000 total
# Google Scholar Author: query results saved as data/AlexandraCristea-SEARCH.csv
# >>> we have 2 hits
# >>> computing metrics
# ./pop8metrics --label "Alexandra Cristea" --format csvh "data/AlexandraCristea-0.csv" data/AlexandraCristea-0-METRICS.csv
# data/AlexandraCristea-0.csv: imported Publish or Perish (CSV) data; 418 publications
# --------Searching: Alexandra Farazouli Stockholm University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Alexandra Farazouli" --format csvh "data/AlexandraFarazouli-0.csv" data/AlexandraFarazouli-0-METRICS.csv
# data/AlexandraFarazouli-0.csv: imported Publish or Perish (CSV) data; 10 publications
# --------Searching: Alistair Willis The Open University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Alistair Willis" --format csvh "data/AlistairWillis-0.csv" data/AlistairWillis-0-METRICS.csv
# data/AlistairWillis-0.csv: imported Publish or Perish (CSV) data; 80 publications
# --------Searching: Amruth Kumar Ramapo College of New Jersey
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Amruth Kumar" --format csvh "data/AmruthKumar-0.csv" data/AmruthKumar-0-METRICS.csv
# data/AmruthKumar-0.csv: imported Publish or Perish (CSV) data; 243 publications
# --------Searching: Ana Mouta Escuela de Doctorado, USAL
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Ana Mouta Escuela de Doctorado, USAL" data/AnaMouta-SEARCH.csv
# Google Scholar Author
# Searching Ana Mouta Escuela de Doctorado, USAL
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 7 hits
# >>> computing metrics
# ./pop8metrics --label "Ana Mouta" --format csvh "data/AnaMouta-6.csv" data/AnaMouta-6-METRICS.csv
# data/AnaMouta-6.csv: imported Publish or Perish (CSV) data; 3 publications
# --------Searching: Andrew Emerson Educational Testing Service
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Andrew Emerson" --format csvh "data/AndrewEmerson-0.csv" data/AndrewEmerson-0-METRICS.csv
# data/AndrewEmerson-0.csv: imported Publish or Perish (CSV) data; 24 publications
# --------Searching: Andrew Lan University of Massachusetts Amherst
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Andrew Lan" --format csvh "data/AndrewLan-0.csv" data/AndrewLan-0-METRICS.csv
# data/AndrewLan-0.csv: imported Publish or Perish (CSV) data; 108 publications
# --------Searching: Andrew Olney University of Memphis
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Andrew Olney" --format csvh "data/AndrewOlney-0.csv" data/AndrewOlney-0-METRICS.csv
# data/AndrewOlney-0.csv: imported Publish or Perish (CSV) data; 160 publications
# --------Searching: Andrew Zamecnik University of South Australia
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Andrew Zamecnik" --format csvh "data/AndrewZamecnik-0.csv" data/AndrewZamecnik-0-METRICS.csv
# data/AndrewZamecnik-0.csv: imported Publish or Perish (CSV) data; 8 publications
# --------Searching: Anett Hoppe TIB Leibniz Information Centre for Science and Technology; L3S Research Centre, Leibniz Universität Hannover
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Anett Hoppe" --format csvh "data/AnettHoppe-0.csv" data/AnettHoppe-0-METRICS.csv
# data/AnettHoppe-0.csv: imported Publish or Perish (CSV) data; 56 publications
# --------Searching: Angel Melendez-Armenta Tecnologico Nacional de Mexico
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Angel Melendez-Armenta" --format csvh "data/AngelMelendezArmenta-0.csv" data/AngelMelendezArmenta-0-METRICS.csv
# data/AngelMelendezArmenta-0.csv: imported Publish or Perish (CSV) data; 12 publications
# --------Searching: Antonio R. Anaya Universidad Nacional de Educacion a Distancia
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Antonio R. Anaya" --format csvh "data/AntonioRAnaya-0.csv" data/AntonioRAnaya-0-METRICS.csv
# data/AntonioRAnaya-0.csv: imported Publish or Perish (CSV) data; 20 publications
# --------Searching: Armelle Brun LORIA - Université de Lorraine
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Armelle Brun" --format csvh "data/ArmelleBrun-0.csv" data/ArmelleBrun-0-METRICS.csv
# data/ArmelleBrun-0.csv: imported Publish or Perish (CSV) data; 150 publications
# --------Searching: Ayan Banerjee Arizona State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Ayan Banerjee" --format csvh "data/AyanBanerjee-0.csv" data/AyanBanerjee-0-METRICS.csv
# data/AyanBanerjee-0.csv: imported Publish or Perish (CSV) data; 157 publications
# --------Searching: Azza Abdullah Alghamdi KAU
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Azza Abdullah Alghamdi KAU" data/AzzaAbdullahAlghamdi-SEARCH.csv
# Google Scholar Author
# Searching Azza Abdullah Alghamdi KAU
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# !!! no hits. repeating search without affiliation
# ./pop8query --gsauthor --author="Azza Abdullah Alghamdi" data/AzzaAbdullahAlghamdi-SEARCH.csv
# Google Scholar Author
# Searching Azza Abdullah Alghamdi
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have -1 hits
# --------Searching: Bastiaan Heeren Open University, The Netherlands
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Bastiaan Heeren" --format csvh "data/BastiaanHeeren-0.csv" data/BastiaanHeeren-0-METRICS.csv
# data/BastiaanHeeren-0.csv: imported Publish or Perish (CSV) data; 88 publications
# --------Searching: Beate Grawemeyer Coventry University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Beate Grawemeyer" --format csvh "data/BeateGrawemeyer-0.csv" data/BeateGrawemeyer-0-METRICS.csv
# data/BeateGrawemeyer-0.csv: imported Publish or Perish (CSV) data; 62 publications
# --------Searching: Ben du Boulay University of Sussex
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Ben du Boulay University of Sussex" data/BenduBoulay-SEARCH.csv
# Google Scholar Author
# Searching Ben du Boulay University of Sussex
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# !!! no hits. repeating search without affiliation
# ./pop8query --gsauthor --author="Ben du Boulay" data/BenduBoulay-SEARCH.csv
# Google Scholar Author
# Searching Ben du Boulay
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have -1 hits
# --------Searching: Benjamin Goldberg United States Army DEVCOM Soldier Center
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Benjamin Goldberg United States Army DEVCOM Soldier Center" data/BenjaminGoldberg-SEARCH.csv
# Google Scholar Author
# Searching Benjamin Goldberg United States Army DEVCOM Soldier Center
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 3 hits
# >>> computing metrics
# ./pop8metrics --label "Benjamin Goldberg" --format csvh "data/BenjaminGoldberg-0.csv" data/BenjaminGoldberg-0-METRICS.csv
# data/BenjaminGoldberg-0.csv: imported Publish or Perish (CSV) data; 156 publications
# --------Searching: Benjamin Nye USC
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Benjamin Nye" --format csvh "data/BenjaminNye-0.csv" data/BenjaminNye-0-METRICS.csv
# data/BenjaminNye-0.csv: imported Publish or Perish (CSV) data; 97 publications
# --------Searching: Bert Bredeweg University of Amsterdam
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Bert Bredeweg" --format csvh "data/BertBredeweg-0.csv" data/BertBredeweg-0-METRICS.csv
# data/BertBredeweg-0.csv: imported Publish or Perish (CSV) data; 350 publications
# --------Searching: Bita Akram North Carolina State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Bita Akram" --format csvh "data/BitaAkram-0.csv" data/BitaAkram-0-METRICS.csv
# data/BitaAkram-0.csv: imported Publish or Perish (CSV) data; 30 publications
# --------Searching: Blair Lehman Educational Testing Service
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Blair Lehman" --format csvh "data/BlairLehman-0.csv" data/BlairLehman-0-METRICS.csv
# data/BlairLehman-0.csv: imported Publish or Perish (CSV) data; 55 publications
# --------Searching: Bruce McLaren CMU
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Bruce McLaren" --format csvh "data/BruceMcLaren-0.csv" data/BruceMcLaren-0-METRICS.csv
# data/BruceMcLaren-0.csv: imported Publish or Perish (CSV) data; 267 publications
# --------Searching: Burak Aksar Boston University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Burak Aksar" --format csvh "data/BurakAksar-0.csv" data/BurakAksar-0-METRICS.csv
# data/BurakAksar-0.csv: imported Publish or Perish (CSV) data; 19 publications
# --------Searching: Carla Limongelli Universita' Roma Tre
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Carla Limongelli" --format csvh "data/CarlaLimongelli-0.csv" data/CarlaLimongelli-0-METRICS.csv
# data/CarlaLimongelli-0.csv: imported Publish or Perish (CSV) data; 120 publications
# --------Searching: Carlos Felipe Rodriguez-Hernandez Tecnologico de Monterrey
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Carlos Felipe Rodriguez-Hernandez" --format csvh "data/CarlosFelipeRodriguezHernandez-0.csv" data/CarlosFelipeRodriguezHernandez-0-METRICS.csv
# data/CarlosFelipeRodriguezHernandez-0.csv: imported Publish or Perish (CSV) data; 19 publications
# --------Searching: Carol Forsyth Educational Testing Service
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Carol Forsyth" --format csvh "data/CarolForsyth-0.csv" data/CarolForsyth-0-METRICS.csv
# data/CarolForsyth-0.csv: imported Publish or Perish (CSV) data; 51 publications
# --------Searching: Carrie Demmans Epp Carrie Demmans Epp
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Carrie Demmans Epp" --format csvh "data/CarrieDemmansEpp-0.csv" data/CarrieDemmansEpp-0-METRICS.csv
# data/CarrieDemmansEpp-0.csv: imported Publish or Perish (CSV) data; 92 publications
# --------Searching: Cesar A. Collazos Full Professor
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Cesar A. Collazos Full Professor" data/CesarACollazos-SEARCH.csv
# Google Scholar Author
# Searching Cesar A. Collazos Full Professor
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# Progress: 2 (of 1000)
# 2 results found; 2 out of maximum 1000 total
# Google Scholar Author: query results saved as data/CesarACollazos-SEARCH.csv
# >>> we have 2 hits
# --- retrieving results for best match 1
# ./pop8query --gsprofile --author="9XuLJBAAAAAJ" data/CesarACollazos-1.csv
# Google Scholar Profile
# Searching [9XuLJBAAAAAJ]
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1155 total
# 0 out of maximum 1000 results; sending next request...
# /z/aolney/software/miniconda3/envs/jlab-3.7/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 100 (of 1000)
# 100 results found; 100 out of maximum 1000 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# 100 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1156 total
# pop8query: Falling out of rate-limiting loop
# 100 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 200 (of 1000)
# 100 results found; 200 out of maximum 1000 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# 200 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1157 total
# pop8query: Falling out of rate-limiting loop
# 200 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 300 (of 1000)
# 100 results found; 300 out of maximum 1000 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# 300 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1158 total
# pop8query: Falling out of rate-limiting loop
# 300 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 400 (of 1000)
# 100 results found; 400 out of maximum 1000 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# 400 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1159 total
# pop8query: Falling out of rate-limiting loop
# 400 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 500 (of 1000)
# 100 results found; 500 out of maximum 1000 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# 500 out of maximum 1000 results; limiting the request rate...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1160 total
# ...
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1171 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# !!! no hits. repeating search without affiliation
# ./pop8query --gsauthor --author="Tanci Simões Gomes
# " data/TanciSimõesGomes-SEARCH.csv
# Google Scholar Author
# Searching Tanci Simões Gomes
#
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1171 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have -1 hits
# --------Searching: Tanja Käser EPFL
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Tanja Käser" --format csvh "data/TanjaKäser-0.csv" data/TanjaKäser-0-METRICS.csv
# data/TanjaKäser-0.csv: imported Publish or Perish (CSV) data; 64 publications
# --------Searching: Tanja Mitrovic Intelligent Computer Tutoring Group, University of Canterbury, Christchurch
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Tanja Mitrovic Intelligent Computer Tutoring Group, University of Canterbury, Christchurch" data/TanjaMitrovic-SEARCH.csv
# Google Scholar Author
# Searching Tanja Mitrovic Intelligent Computer Tutoring Group, University of Canterbury, Christchurch
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1171 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 2 hits
# >>> computing metrics
# ./pop8metrics --label "Tanja Mitrovic" --format csvh "data/TanjaMitrovic-0.csv" data/TanjaMitrovic-0-METRICS.csv
# data/TanjaMitrovic-0.csv: imported Publish or Perish (CSV) data; 55 publications
# --------Searching: Teng Guo  Jinan University
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Teng Guo  Jinan University" data/TengGuo-SEARCH.csv
# Google Scholar Author
# Searching Teng Guo  Jinan University
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1171 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 7 hits
# --- retrieving results for best match 2
# ./pop8query --gsprofile --author="STHi_s4AAAAJ" data/TengGuo-2.csv
# Google Scholar Profile
# Searching [STHi_s4AAAAJ]
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1171 total
# 0 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 21 (of 1000)
# 21 results found; 21 out of maximum 1000 total
# Google Scholar Profile: query results saved as data/TengGuo-2.csv
# >>> computing metrics
# ./pop8metrics --label "Teng Guo " --format csvh "data/TengGuo-2.csv" data/TengGuo-2-METRICS.csv
# data/TengGuo-2.csv: imported Publish or Perish (CSV) data; 21 publications
# --------Searching: Tenzin Doleck Simon Fraser University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Tenzin Doleck" --format csvh "data/TenzinDoleck-0.csv" data/TenzinDoleck-0-METRICS.csv
# data/TenzinDoleck-0.csv: imported Publish or Perish (CSV) data; 118 publications
# --------Searching: Thomas Price North Carolina State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Thomas Price" --format csvh "data/ThomasPrice-0.csv" data/ThomasPrice-0-METRICS.csv
# data/ThomasPrice-0.csv: imported Publish or Perish (CSV) data; 92 publications
# --------Searching: Tomohiro Nagashima Saarland University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Tomohiro Nagashima" --format csvh "data/TomohiroNagashima-0.csv" data/TomohiroNagashima-0-METRICS.csv
# data/TomohiroNagashima-0.csv: imported Publish or Perish (CSV) data; 47 publications
# --------Searching: Tomoo Inoue University of Tsukuba
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Tomoo Inoue" --format csvh "data/TomooInoue-0.csv" data/TomooInoue-0-METRICS.csv
# data/TomooInoue-0.csv: imported Publish or Perish (CSV) data; 1000 publications
# --------Searching: Tracy Arner Arizona State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Tracy Arner" --format csvh "data/TracyArner-0.csv" data/TracyArner-0-METRICS.csv
# data/TracyArner-0.csv: imported Publish or Perish (CSV) data; 25 publications
# --------Searching: Traian Rebedea University Politehnica of Bucharest
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Traian Rebedea" --format csvh "data/TraianRebedea-0.csv" data/TraianRebedea-0-METRICS.csv
# data/TraianRebedea-0.csv: imported Publish or Perish (CSV) data; 197 publications
# --------Searching: Vanda Luengo Sorbonne Université
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vanda Luengo" --format csvh "data/VandaLuengo-0.csv" data/VandaLuengo-0-METRICS.csv
# data/VandaLuengo-0.csv: imported Publish or Perish (CSV) data; 234 publications
# --------Searching: Vanessa Echeverria Monash University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vanessa Echeverria" --format csvh "data/VanessaEcheverria-0.csv" data/VanessaEcheverria-0-METRICS.csv
# data/VanessaEcheverria-0.csv: imported Publish or Perish (CSV) data; 61 publications
# --------Searching: Vania Dimitrova University of Leeds
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vania Dimitrova" --format csvh "data/VaniaDimitrova-0.csv" data/VaniaDimitrova-0-METRICS.csv
# data/VaniaDimitrova-0.csv: imported Publish or Perish (CSV) data; 260 publications
# --------Searching: Vasile Rus The University of Memphis
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vasile Rus" --format csvh "data/VasileRus-0.csv" data/VasileRus-0-METRICS.csv
# data/VasileRus-0.csv: imported Publish or Perish (CSV) data; 442 publications
# --------Searching: Vincent Wade Trinity College Dublin
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vincent Wade" --format csvh "data/VincentWade-0.csv" data/VincentWade-0-METRICS.csv
# data/VincentWade-0.csv: imported Publish or Perish (CSV) data; 388 publications
# --------Searching: Vinitra Swamy EPFL
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Vinitra Swamy" --format csvh "data/VinitraSwamy-0.csv" data/VinitraSwamy-0-METRICS.csv
# data/VinitraSwamy-0.csv: imported Publish or Perish (CSV) data; 14 publications
# --------Searching: Vitomir Kovanovic The University of South Australia
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Vitomir Kovanovic The University of South Australia" data/VitomirKovanovic-SEARCH.csv
# Google Scholar Author
# Searching Vitomir Kovanovic The University of South Australia
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 2 hits
# >>> computing metrics
# ./pop8metrics --label "Vitomir Kovanovic" --format csvh "data/VitomirKovanovic-0.csv" data/VitomirKovanovic-0-METRICS.csv
# data/VitomirKovanovic-0.csv: imported Publish or Perish (CSV) data; 107 publications
# --------Searching: Wania Cavalcanti Universidade Federal do Rio de Janeiro COPPEAD
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Wania Cavalcanti Universidade Federal do Rio de Janeiro COPPEAD" data/WaniaCavalcanti-SEARCH.csv
# Google Scholar Author
# Searching Wania Cavalcanti Universidade Federal do Rio de Janeiro COPPEAD
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# !!! no hits. repeating search without affiliation
# ./pop8query --gsauthor --author="Wania Cavalcanti" data/WaniaCavalcanti-SEARCH.csv
# Google Scholar Author
# Searching Wania Cavalcanti
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have -1 hits
# --------Searching: Wayne Holmes UCL
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Wayne Holmes" --format csvh "data/WayneHolmes-0.csv" data/WayneHolmes-0-METRICS.csv
# data/WayneHolmes-0.csv: imported Publish or Perish (CSV) data; 110 publications
# --------Searching: Wenbin Gan National Institute of Information and Communications Technology
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Wenbin Gan" --format csvh "data/WenbinGan-0.csv" data/WenbinGan-0-METRICS.csv
# data/WenbinGan-0.csv: imported Publish or Perish (CSV) data; 30 publications
# --------Searching: Wookhee Min North Carolina State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Wookhee Min" --format csvh "data/WookheeMin-0.csv" data/WookheeMin-0-METRICS.csv
# data/WookheeMin-0.csv: imported Publish or Perish (CSV) data; 81 publications
# --------Searching: Yang Jiang Columbia University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Yang Jiang" --format csvh "data/YangJiang-0.csv" data/YangJiang-0-METRICS.csv
# data/YangJiang-0.csv: imported Publish or Perish (CSV) data; 27 publications
# --------Searching: Yeojin Kim North Carolina State University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Yeojin Kim" --format csvh "data/YeojinKim-0.csv" data/YeojinKim-0-METRICS.csv
# data/YeojinKim-0.csv: imported Publish or Perish (CSV) data; 39 publications
# --------Searching: Yo Ehara Tokyo Gakugei University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Yo Ehara" --format csvh "data/YoEhara-0.csv" data/YoEhara-0-METRICS.csv
# data/YoEhara-0.csv: imported Publish or Perish (CSV) data; 58 publications
# --------Searching: Yu Lu Beijing Normal University
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Yu Lu Beijing Normal University" data/YuLu-SEARCH.csv
# Google Scholar Author
# Searching Yu Lu Beijing Normal University
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# Progress: 2 (of 1000)
# 2 results found; 2 out of maximum 1000 total
# Google Scholar Author: query results saved as data/YuLu-SEARCH.csv
# >>> we have 2 hits
# >>> computing metrics
# ./pop8metrics --label "Yu Lu" --format csvh "data/YuLu-0.csv" data/YuLu-0-METRICS.csv
# data/YuLu-0.csv: imported Publish or Perish (CSV) data; 94 publications
# --------Searching: Yun Huang Carnegie Mellon University
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Yun Huang Carnegie Mellon University" data/YunHuang-SEARCH.csv
# Google Scholar Author
# Searching Yun Huang Carnegie Mellon University
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 46 hits
# --- retrieving results for best match 17
# ./pop8query --gsprofile --author="s3OiQxsAAAAJ" data/YunHuang-17.csv
# Google Scholar Profile
# Searching [s3OiQxsAAAAJ]
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1172 total
# 0 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 41 (of 1000)
# 41 results found; 41 out of maximum 1000 total
# Google Scholar Profile: query results saved as data/YunHuang-17.csv
# >>> computing metrics
# ./pop8metrics --label "Yun Huang" --format csvh "data/YunHuang-17.csv" data/YunHuang-17-METRICS.csv
# data/YunHuang-17.csv: imported Publish or Perish (CSV) data; 41 publications
# --------Searching: Zitao Liu Jinan University
# +++ using cached search
# >>> we have 1 hits
# >>> computing metrics
# ./pop8metrics --label "Zitao Liu" --format csvh "data/ZitaoLiu-0.csv" data/ZitaoLiu-0-METRICS.csv
# data/ZitaoLiu-0.csv: imported Publish or Perish (CSV) data; 126 publications
# --------Searching: Zixi Chen University of Minnesota, USA
# --- multiple hits on previous search. attempting to narrow.
# ./pop8query --gsauthor --author="Zixi Chen University of Minnesota, USA" data/ZixiChen-SEARCH.csv
# Google Scholar Author
# Searching Zixi Chen University of Minnesota, USA
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1173 total
# pop8query: GSAuthor: HTTP response status 200 (OK)
# pop8query: GSAuthor: 0 results after query
# Warning: No results found; 0 total
# pop8query: GSAuthor: no results; forcing error result: [514] No matching data found (0 - 0 results)
# pop8query: query(0x60000001) Search ended with error 514: No matching data found 0 results (unattended) ==> 0x00000001=OK
# Google Scholar Author: query failed: No matching data found
# >>> we have 4 hits
# --- retrieving results for best match 2
# ./pop8query --gsprofile --author="zfkOwi4AAAAJ" data/ZixiChen-2.csv
# Google Scholar Profile
# Searching [zfkOwi4AAAAJ]
# Progress: 0 (of 1000)
# 0/0/0 rpm, 0/10m, 0/1h, 0/4h, 1173 total
# 0 out of maximum 1000 results; sending next request...
# pop8query: GSProfile: HTTP response status 200 (OK)
# Progress: 17 (of 1000)
# 17 results found; 17 out of maximum 1000 total
# Google Scholar Profile: query results saved as data/ZixiChen-2.csv
# >>> computing metrics
# ./pop8metrics --label "Zixi Chen" --format csvh "data/ZixiChen-2.csv" data/ZixiChen-2-METRICS.csv
# data/ZixiChen-2.csv: imported Publish or Perish (CSV) data; 17 publications

# %% [markdown]
# ## Merge data

# %%
import pandas as pd
import os

# because of how we managed caching, we prefer the highest metrics file by n (i.e. if we had n=0 in the cache and later added n=6, then we prefer n=6 because that has been disambiguated)
max_n = {}
filenames = [ file for file in os.listdir("data")  if file.endswith("METRICS.csv")]
for filename in filenames:
    name,n,_ = filename.split("-")
    if not name in max_n or int(n) > 0:
        max_n[name]=n

# save out profiles where a semantic match was used to identify the profile for extra vetting
with open('best-guesses.txt', 'w') as f:
    nonzero_n = [ (name + "," + n +"\n") for name,n in max_n.items() if matches(name) > 2]
    f.writelines(nonzero_n)
        
# metrics_dfs = [ pd.read_csv("data/"+file) for file in os.listdir("data")  if file.endswith("METRICS.csv")]

# merge all metrics files using caching
metrics_dfs = [ pd.read_csv("data/"+name+"-"+n+"-METRICS.csv") for name,n in max_n.items()]
df_metrics = pd.concat(metrics_dfs)
# metrics_dfs = [ pd.read_csv("data/"+name+"-"+n+"-METRICS.csv") for name,n in max_n.items()]

# create indicator column for number of matches
df_metrics['matches'] = df_metrics['label'].apply(lambda x: matches(x)-1)

# create column for profile url used
name_url_map = {}
filenames = [ file for file in os.listdir("data")  if file.endswith("SEARCH.csv")]
for filename in filenames:
    df = pd.read_csv("data/"+filename)
    name,_ = filename.split("-")
    name_url_map[name] = list(df[['Authors','ArticleURL']].itertuples(index=False, name=None)) 
df_metrics['scholar name'] = df_metrics['label'].apply(lambda x: name_url_map[safe_name(x)][int(max_n[safe_name(x)])][0] )
df_metrics['scholar url'] = df_metrics['label'].apply(lambda x: "=HYPERLINK(\""+name_url_map[safe_name(x)][int(max_n[safe_name(x)])][1] +"\")")
# df_metrics['scholar url'] = df_metrics['label'].apply(lambda x: "\"=HYPERLINK(\"\""+name_url_map[safe_name(x)][int(max_n[safe_name(x)])][1] +"\"\")\"")

# reorder the columns
col_names = df_metrics.columns.tolist()
col_names =  col_names[0:1] + col_names[-3:] + col_names[1:-3]
df_metrics = df_metrics[col_names]

# write out metrics
df_metrics.to_csv("metrics.csv",index=False)

# append missing names to csv
with open("missing-names.txt", "r") as f:
    missing = f.readlines()
with open('metrics.csv', 'a') as f:
    f.writelines(missing)
    
    
#calculate missing (only needed if missing-names failed)
# df_metrics[-df_metrics['label'].isin(names)] 
# found = df_metrics['label'].tolist()
# set(names).difference(set(found))

# %%
CLEAR NONZERO FILES (UNCOMMENTED ON PURPOSE)
filenames = [ file for file in os.listdir("data")  if file.endswith("METRICS.csv")]
for filename in filenames:
    name,n,_ = filename.split("-")
    if n != "0":
        os.remove("data/"+filename)
# Out:
#   File "/tmp/ipykernel_25255/3361420575.py", line 1
#     CLEAR NONZERO FILES (UNCOMMENTED ON PURPOSE)
#                 ^
# SyntaxError: invalid syntax
